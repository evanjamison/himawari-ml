# %% [markdown]
# # Exploration\nUse this notebook for quick visual checks.\n

# %%
import numpy as np\nfrom PIL import Image\nfrom pathlib import Path\n\nimg = Image.open(Path('data/interim/latest_resized.png'))\nimg\n
